# %% [markdown]
# ## Initial account analysis
# Tayae Rogers, 3/12/2024

# %%
import os
import csv
from collections import defaultdict
import pandas as pd
import re
import json

# %%
def list_of_news_accs(csv_in):
    """
    Takes news acc CSV (our shared Google Sheets file) and returns a list of news accounts
    """
    file = f"{csv_in}.csv"
    news_accs = []
    with open(file, mode ='r')as file:
        csvFile = csv.reader(file)
        for lines in csvFile:
            news_accs.append(lines[0])
    return news_accs

# %%
wd = "/Users/tayaerogers/Documents/MEDSL/GitHub/CS315-Project-2" # put personal wd ending in "/CS315-Project-2" here
account_wd = wd + "/analysis/news_accs/"
news_accs = list_of_news_accs(os.path.join(account_wd, 'news_accounts_03112024'))
news_accs
# Out:
# ['nytimes',
#  'washingtonpost',
#  'cnn',
#  'pbsnews',
#  'abcnews',
#  'msnbc',
#  'cbsnews',
#  'briantylercohen',
#  'cbseveningnews',
#  'abcworldnews',
#  'nbcnews',
#  'yahoonews',
#  '7newsq',
#  '',
#  'skynews',
#  'bbc',
#  'forbes',
#  'usatoday',
#  'gbnews',
#  'varietymagazine',
#  'sophiasmithgaler',
#  'maxfostercnn',
#  'nytopinion',
#  '60minutes',
#  'cbsmornings',
#  'cbssundaymorning',
#  'vicenews',
#  'abcnewslive',
#  'gma',
#  'newsweek',
#  'underthedesknews',
#  'theconversation',
#  'nowthisimpact ',
#  'dailymail',
#  'davebondy',
#  'aljazeeraenglish',
#  'vicenewsdocs',
#  'c4news',
#  'itvnews',
#  'niickjackson',
#  'abc7la',
#  'reuters',
#  'npr',
#  'nowthis',
#  'brutamerica',
#  'thetelegraph',
#  'vox',
#  'buzzfeednews',
#  'taylorlorenz',
#  'wallstreetjournal',
#  'latimes',
#  'natgeo',
#  'vicderbyshire',
#  'pinknews',
#  'eveningstandard',
#  'cleoabram',
#  'sandragathmann',
#  'tldrnews',
#  'morningbrew',
#  'semafor',
#  'thepocketreport',
#  'theeconomist',
#  'thegarbagequeen',
#  'nbcnightlynews',
#  'benjaminzamoratven',
#  'thenewsmovement',
#  'elliecolts',
#  'gullyburrows',
#  'jacksurfleet ',
#  'washingtonpostlive',
#  'washingtonpostwellbeing',
#  'nbc.news_us',
#  'bbcnews ',
#  'cbcnews',
#  'radiodisney ',
#  'enews ',
#  'goodmorningbadnews',
#  'newus197655',
#  'catchupnews',
#  'nbc10boston',
#  'realandyhidalgo',
#  'homelandscanner',
#  'meganhealytv',
#  'Nehagohil.24',
#  'clogrifff',
#  'abbiedewhurst',
#  'noticiastelemundo',
#  'noticiascaracol ',
#  'uninoticias',
#  'aztecanoticias',
#  'migracionnoticias',
#  'noticiasgt0',
#  'notici05',
#  'imagennoticias ',
#  'noticias.ilustradas',
#  'noticiasnewsnic',
#  'ultimasnoticias8',
#  'colglobalnews',
#  'meganoticias.cl',
#  'americanoticias',
#  'noticias_mundotv',
#  'noticiasredetv',
#  'jennalynn468',
#  'dylan.page',
#  'jamesgetspolitical',
#  'js.news17',
#  'metro_tv',
#  'republikaonline',
#  'liputan6.sctv',
#  'khaosodonline',
#  'thairath_news',
#  'tv_asahi_news',
#  'thaipbsnews',
#  '501awani',
#  'vicenews',
#  'thesun',
#  'georgia_coan',
#  'amandadcnn',
#  'katiepolglasecnn',
#  'vandamcnn',
#  'maddowshow',
#  'guardian',
#  'openlynews',
#  'chris.ship.royal',
#  'franceswangtv',
#  'jaketapper',
#  'gadischwartz',
#  'staytunednbc',
#  'watchsavannah',
#  'theatlantic',
#  'newyorker',
#  'huffpost',
#  'buzzfeednow',
#  'huffpostuk',
#  'phillyinquirer',
#  'newsday.tv ',
#  'citizen.digital',
#  'ntvkenya',
#  'habari_njema',
#  'tiin.worldnews ',
#  'aljazeera',
#  'newsnexussa',
#  '2nacheki',
#  'dw24tv',
#  'dailyglobalnewsshorts',
#  'royalnewschannel',
#  'update_438',
#  'rbarwanda',
#  'igihe',
#  'newschannelakp',
#  'leoandroccosounds',
#  'breakingnews1134',
#  'nigeriaglobalnews',
#  'newtimesrwanda',
#  'infos.minutes',
#  'unvelingtruth945',
#  'todayshow',
#  'nbcsports',
#  'nfl',
#  'therecount',
#  'bnc_news',
#  'thebryanjun',
#  'todayonline',
#  'news.daily4',
#  'todaysworldnews',
#  'newsworld5555',
#  'durikoreannews',
#  'thomasgermain',
#  'speedifylive',
#  'bernardgarby',
#  'thestanzamedia',
#  'thefacemagazine',
#  'plasticsnews',
#  'nownownews',
#  'thegoodnews100',
#  'sambentley',
#  'latinus_us',
#  'dallasmorningnews',
#  'bostonglobe',
#  'globeopinion',
#  'bostonglobetoday ',
#  'espn',
#  'time',
#  'skysports',
#  'skysportswsl',
#  'geonews',
#  '11thhourmsnbc',
#  'bolnews',
#  'cgtneurope',
#  'scmp.news',
#  'peoplesdaily',
#  'middleeasteye',
#  'businessinsider',
#  'cmlvancover',
#  'apnews',
#  'btnewsroom',
#  'trtworld ',
#  'cspanofficial',
#  'trtarabi',
#  'bloomberg',
#  'bloombergpolitics',
#  'bloombergbusiness',
#  'politicomx',
#  'foxnewsanytime',
#  'bostondotcom',
#  'abc7chicago',
#  'vox_espana',
#  'bloombergopinion',
#  'bloomberglaw',
#  'catoinstitute',
#  'startribune',
#  'johannaruediger',
#  'euronews.tv',
#  'bbcnewsbrasil',
#  'geonewsheadlines.pk',
#  '9news',
#  'news_389_us',
#  'news.show.h24',
#  'vtcnews',
#  'gmanews',
#  'kbc_news',
#  'orient_newsar',
#  'daily.news65',
#  'newsnationnow',
#  'ch7hd_news',
#  'us.breakingnews',
#  'arynews.official ',
#  'empact_news',
#  'newsguy38',
#  'real.benshapiro',
#  'joepags',
#  'newbreaking20231',
#  'vicenews',
#  'univision',
#  'therealisticfishhead',
#  'bbcnewsmundo',
#  'marcus.dipaola',
#  'businessinsideres',
#  'businessinsiderfr',
#  'businessinsidermx',
#  'yahoofinance',
#  'yahoobrasil',
#  'yahoouk',
#  'yahooaustralia',
#  'yahoosea',
#  'worldeconomicforum',
#  'wired',
#  'who',
#  'voguemagazine',
#  'voguegermany',
#  'vogueitalia',
#  'vice_spain',
#  'thestarmalaysia',
#  'nypost',
#  'asianewschannels',
#  'theetinalove',
#  'worldnewstoday2024',
#  'worldnewscoverage',
#  'worldlymap',
#  'msnbc',
#  'dailymirror',
#  'the.discloser',
#  'newweather1',
#  'news.tracking',
#  'facethenation',
#  'kellermankomedy',
#  'tedtok',
#  'ahhhamdan',
#  'wffnews',
#  'tonynew1501',
#  'abc7ny',
#  'abc13houston',
#  '6abcactionews',
#  'fox29philadelphia',
#  'fox2detroitwjbk',
#  'fox5_atlanta',
#  'wesh2orlando',
#  'nbcchicago',
#  'nbcwashington',
#  'washingtonianmag',
#  'ksatnews',
#  'wbznewsradio',
#  'b25news\n',
#  'rtenews',
#  'rocanews',
#  'freeda_en ',
#  'lanacioncom',
#  '\nsomegoodnewsofficial',
#  'thewellesleynews',
#  'dnews247',
#  'nasnewsdaily',
#  'siamnews',
#  'dzrhnews',
#  'joshhelfgott',
#  'pulselivekenya',
#  'ajplus',
#  'valerisssh',
#  '48hourscbs',
#  'kellermankomedy',
#  'usnews',
#  'newsfash',
#  'consumerreports',
#  'sustainableliz_',
#  'errol.barnett',
#  'reamichellew',
#  'planetmoney',
#  'kylascan',
#  'gingerzee',
#  'itsrachelscott',
#  'mynytimes',
#  'nytopinion',
#  'theathletic ',
#  'motherboardvice',
#  'zarahsultanamp',
#  'hanakomontgomery',
#  'viceontv',
#  'viceenespanol',
#  'uninoticias',
#  'future_explored',
#  'weisstech',
#  'tech.news3',
#  'mbtechnews',
#  'daily.tech.news',
#  'dailynewsonline',
#  'batamnews',
#  'deutschlandnews2',
#  'jovempannews',
#  'hypenews.ru',
#  'theglobalworldnews',
#  '3plusnews',
#  'sindonews',
#  'womannews.vn',
#  'chinanewsservice',
#  'cincainews',
#  'newstify',
#  'kompastvnews',
#  'livenews64',
#  'news_livesa',
#  'wereportnews',
#  'tribunnewssultraofficial',
#  'independennews.com',
#  'malaysianupdatenews',
#  'alarabytvnews',
#  'morningnewsch3',
#  'hygonews',
#  'bleacherreport',
#  'nessadiosdado',
#  'crimedivewithjess2.0',
#  'hebewiththenews',
#  'dailyfishtoknews',
#  'thedailydripmedia',
#  'thatgoodnewsgirl',
#  'newsninja',
#  'chroniclesofolivia',
#  'sbsnews_au',
#  'mustsharenews',
#  'luxinews',
#  'filonews',
#  'tribunkaltim.co',
#  'ctvnews',
#  'matta_of_fact',
#  'serranewsrj',
#  'visi.news',
#  'astrogempak',
#  'abc30_actionnews',
#  'abc7newsbayarea',
#  'abc7chicago',
#  '6abcactionnews',
#  'abc7ny',
#  'gma',
#  'kbsnewsofficial',
#  'sbsnews',
#  'kjmbc_news',
#  'bbcnews',
#  'sbsnews_au',
#  'mbs.news',
#  'mtvnews',
#  'knxnews',
#  'jtbcnews_official',
#  'ytnnews',
#  'oscars',
#  'abcnewslive',
#  'abcgma3',
#  'abc13houston',
#  'benjaminzamoratven\n',
#  'accuweather',
#  'manchesternews',
#  'lawandcrime',
#  '48hourscbs',
#  'insideedition',
#  'thomasrhanson',
#  'norahodonnell',
#  'nowthisearth',
#  'mehdihasanshow',
#  'reidout',
#  'katiephang',
#  'watchsavannah',
#  'meetthePress',
#  'niikjackson',
#  'aljazeeraenglish',
#  'bloombergpolitics',
#  'wordlymap',
#  'utusantvofficial',
#  'underthedesknews',
#  'charlesmblow',
#  'bbcsport',
#  'hollywoodreporter',
#  'omarjimeneztok',
#  'mayaeaglin',
#  'laurajarrettnbc',
#  'craigmelvinnbc',
#  'arimelber',
#  'andykaczynski',
#  'hodaandjenna',
#  'nbcsandiego',
#  'jenpsaki',
#  'tomllamasnbc',
#  'tvkatesnow',
#  'journalsentinel',
#  'nbcnewyork',
#  'nbcsouthflorida',
#  'nbcbayarea',
#  'nbcconnecticut',
#  'nbcla',
#  'vnexpress.international',
#  'vietnamnews.official',
#  'nextshark',
#  'insight_official',
#  'insight_fashion',
#  'insight_beauty',
#  'insight_food',
#  'starnewskorea',
#  'subusunews.official',
#  'yonhapnews',
#  'weathernewslive',
#  'youkhino',
#  'news_cool',
#  'officialinews',
#  'ntv.news',
#  'news_postseven',
#  'ktlanews',
#  '5wcvb',
#  'news5everywhere',
#  'newscientist']

# %% [markdown]
# ## Return dataframe with posts whose poster matches ours news account list

# %%
def get_hashtags(phrase):
    """"
    Takes a string phase and returns a list of hashtags
    """
    if isinstance(phrase,str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

# %%
def news_poster_abundance(path):
    all_news = pd.DataFrame(columns = ["video_id", "author_username", "video_description", "hashtags", "suggested_words", "file_name"])
    stats_df = pd.DataFrame(columns = ["file_name", "full_length", "news_length", "prop_news"])
    prefixed = [filename for filename in os.listdir(path) if filename.startswith("Sec2Gr3")]
    
    for file in prefixed:
        meta_csv = pd.read_csv(os.path.join(path,file))
        meta_csv["hashtags"] = meta_csv['video_description'].apply(get_hashtags) # doing this just in case we want the hashtag data later

        meta_sub_df = meta_csv[["video_id", "author_username", "video_description", "hashtags", "suggested_words"]].copy()
        meta_sub_df["file_name"] = str(file)
        news_df = meta_sub_df[meta_sub_df["author_username"].isin(news_accs)]

        allLen = meta_csv.shape[0]
        newsLen = news_df.shape[0]
        propNews = newsLen/allLen
        stats_df.loc[len(stats_df.index)] = [str(file), allLen, newsLen, propNews]  

        all_news = pd.concat([all_news, news_df])
    
    return (stats_df, all_news)

# %%
curr_path = f"{wd}/pre-processing/metadata-csv"
curr_path
# Out:
# '/Users/tayaerogers/Documents/MEDSL/GitHub/CS315-Project-2/pre-processing/metadata-csv'

# %%
news_by_poster = news_poster_abundance(curr_path)[1]
news_by_poster
# Out:
#                  video_id author_username  \
# 341   6988185257426128133             gma
# 204   7283179469001461035         nbcnews
# 353   6948100100992322821         cbsnews
# 610   7307673039922105643           wired
# 1343  7306609553305652510         nbcnews
# ...                   ...             ...
# 8228  7288868567003614510       todayshow
# 8283  7267091322559843616         bbcnews
# 8337  7287837532161625377   middleeasteye
# 8891  7285777286316510470         ctvnews
# 8899  7284629865473625387            espn
#
#                                       video_description  \
# 341   Morgan Wallen is speaking out to address using...
# 204   After wrapping "#Scandal," #KerryWashington's ...
# 353   A baby kangaroo is rescued from its mother’s p...
# 610   Elmo is here to set the record straight, once ...
# 1343  Former President #JimmyCarter and former first...
# ...                                                 ...
# 8228  #taylorswift has arrived at the #tserastourmov...
# 8283  One Hawaii resident says some tourists are car...
# 8337  Palestinian ambassador to the UK blasts the BB...
# 8891  If you’re stuck in traffic on Hwy. 400 Tuesday...
# 8899  What a tackle though 😂 (via @Matt Jensen) #bas...
#
#                                                hashtags  \
# 341                                [news, morganwallen]
# 204                 [scandal,", kerrywashington's, dna]
# 353                                   [news, australia]
# 610   [elmo., sesamestreet, newyorker, newyorkaccent...
# 1343                      [jimmycarter, rosalynncarter]
# ...                                                 ...
# 8228                     [taylorswift, tserastourmovie]
# 8283  [lahaina, maui, hawaii, hawaiifire, wildfire, ...
# 8337  [bbc, israel, palestinian, ambassador, gaza, l...
# 8891  [breakingnews, truck, highway, ontario, gta, t...
# 8899                [baseball, football, tackle, funny]
#
#                                         suggested_words          file_name
# 341   morgan wallen racist video, morgan wallen, mor...  Sec2Gr3_77777.csv
# 204   shera kerry washington, kerry washington somal...  Sec2Gr3_77217.csv
# 353   kangaroo pouch, Kangaroo, baby kangaroo, Anima...  Sec2Gr3_77217.csv
# 610   elmo, elmo funniest moments, elmo balsamicvine...  Sec2Gr3_77217.csv
# 1343                                                NaN  Sec2Gr3_77217.csv
# ...                                                 ...                ...
# 8228                                                NaN  Sec2Gr3_74721.csv
# 8283  hawaii tourists, maui tourists, hawaii, Lahain...  Sec2Gr3_74721.csv
# 8337                                                NaN  Sec2Gr3_74721.csv
# 8891                                                NaN  Sec2Gr3_74721.csv
# 8899                                                NaN  Sec2Gr3_74721.csv
#
# [86 rows x 6 columns]

# %%
news_by_poster.to_csv(f"{wd}/analysis/news_accs/news_by_poster.csv", index=False)
